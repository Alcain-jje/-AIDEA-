# %%
import pandas as pd 

train_data = pd.read_csv('C:\\Users\\ox797\\Desktop\\크롤링 데이터\\train_data.csv',encoding='utf-8')
test_data = pd.read_csv('C:\\Users\\ox797\\Desktop\\크롤링 데이터\\test_data.csv',encoding='utf-8')

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
train_data['label'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#print(train_data.groupby('label').size().reset_index(name='count'))
#print(test_data.groupby('label').size().reset_index(name='count'))

# %%
stopwords = ['의', '가', '이', '은', '들', '는', '좀', '잘', '걍', '과', '도', '를', '으로', '자', '에', '와', '한', '하다']

# %%
import konlpy 
from konlpy.tag import Okt 

okt = Okt() 
X_train = []

for sentence in train_data['title']: 
    temp_X = [] 
    temp_X = okt.morphs(sentence, stem=True)
    temp_X = [word for word in temp_X if not word in stopwords]
    X_train.append(temp_X)

X_test = [] 
for sentence in test_data['title']: 
    temp_X = []
    temp_X = okt.morphs(sentence, stem=True) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    X_test.append(temp_X)

# %%
X_train
# Out:
# [['사진',
#   '피',
#   '코크',
#   '그릭',
#   '요거트',
#   '이번',
#   '처음',
#   '사보다',
#   '\n',
#   '9',
#   '개월',
#   '아기',
#   '요거트',
#   '쌀',
#   '찐빵',
#   '만',
#   '들어주다',
#   '\n',
#   '대',
#   '용량',
#   '가격',
#   '착하다',
#   '좋다',
#   'ㅎㅎ',
#   '\n',
#   '만들다',
#   '방법',
#   '특별하다',
#   '어렵다',
#   '않다',
#   '\n',
#   '요거트',
#   '계란',
#   '노른자',
#   '분리',
#   '넣다',
#   '\n',
#   '쌀',
#   '가루',
#   '로',
#   '농도',
#   '조절',
#   '하',
#   '며',
#   '반죽',
#   '\n',
#   '혹시',
#   '단맛',
#   '없다',
#   '안',
#   '먹다',
#   '싶다',
#   '\n',
#   '단호박',
#   '큐브',
#   '만들다',
#   '놓다',
#   '거',
#   '송송',
#   '다지다',
#   '넣다',
#   'ㅎㅎ',
#   '\n',
#   '찌다',
#   '찌',
#   '니까',
#   '폭',
#   '신',
#   '폭신',
#   '몰랑몰랑하다',
#   'ㅎㅎ',
#   '\n',
#   '너무',
#   '반죽',
#   '지다',
#   '같다',
#   '오븐',
#   '에도',
#   '살짝',
#   '돌려주다',
#   '\n',
#   '요거트',
#   '향',
#   '나다',
#   '어른',
#   '입맛',
#   '엔',
#   '밍밍',
#   '\n',
#   '아이',
#   '주',
#   '도식',
#   '중',
#   '인데',
#   '아이',
#   '손',
#   '바로',
#   '가다',
#   'ㅎㅎ',
# ...

# %%
X_train = [v for v in X_train if v]

# %%
X_train
# Out:
# [['사진',
#   '피',
#   '코크',
#   '그릭',
#   '요거트',
#   '이번',
#   '처음',
#   '사보다',
#   '\n',
#   '9',
#   '개월',
#   '아기',
#   '요거트',
#   '쌀',
#   '찐빵',
#   '만',
#   '들어주다',
#   '\n',
#   '대',
#   '용량',
#   '가격',
#   '착하다',
#   '좋다',
#   'ㅎㅎ',
#   '\n',
#   '만들다',
#   '방법',
#   '특별하다',
#   '어렵다',
#   '않다',
#   '\n',
#   '요거트',
#   '계란',
#   '노른자',
#   '분리',
#   '넣다',
#   '\n',
#   '쌀',
#   '가루',
#   '로',
#   '농도',
#   '조절',
#   '하',
#   '며',
#   '반죽',
#   '\n',
#   '혹시',
#   '단맛',
#   '없다',
#   '안',
#   '먹다',
#   '싶다',
#   '\n',
#   '단호박',
#   '큐브',
#   '만들다',
#   '놓다',
#   '거',
#   '송송',
#   '다지다',
#   '넣다',
#   'ㅎㅎ',
#   '\n',
#   '찌다',
#   '찌',
#   '니까',
#   '폭',
#   '신',
#   '폭신',
#   '몰랑몰랑하다',
#   'ㅎㅎ',
#   '\n',
#   '너무',
#   '반죽',
#   '지다',
#   '같다',
#   '오븐',
#   '에도',
#   '살짝',
#   '돌려주다',
#   '\n',
#   '요거트',
#   '향',
#   '나다',
#   '어른',
#   '입맛',
#   '엔',
#   '밍밍',
#   '\n',
#   '아이',
#   '주',
#   '도식',
#   '중',
#   '인데',
#   '아이',
#   '손',
#   '바로',
#   '가다',
#   'ㅎㅎ',
# ...

# %% [markdown]
# 정수인코딩

# %%
from keras.preprocessing.text import Tokenizer 
max_words = 35000
tokenizer = Tokenizer(num_words = max_words) 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
print(X_train[:3])
# Out:
# [[17, 265, 268, 60, 31, 195, 141, 205, 4, 2677, 918, 81, 31, 2066, 4216, 65, 2678, 4, 261, 556, 26, 358, 1, 56, 4, 115, 1175, 944, 756, 21, 4, 31, 619, 1518, 1124, 59, 4, 2066, 782, 32, 1282, 2341, 119, 1519, 1176, 4, 1221, 296, 46, 55, 3, 203, 4, 4217, 3197, 115, 381, 67, 3198, 1622, 59, 56, 4, 377, 2342, 709, 1904, 976, 4218, 4219, 56, 4, 11, 1176, 513, 27, 320, 213, 243, 1905, 4, 31, 278, 99, 1177, 382, 167, 1038, 4, 18, 283, 4220, 111, 175, 18, 630, 196, 214, 56, 4, 1362, 887, 1080], [17, 60, 31, 1906, 167, 11, 317, 148, 4, 142, 284, 31, 79, 129, 493, 314, 1440, 65, 44, 459], [17, 141, 50, 20, 386, 316, 859, 674, 272, 5, 710, 2, 27, 96, 105, 3, 20]]

# %%
print("리뷰 최대 길이 : ", max(len(l) for l in X_train)) 
print("리뷰 평균 길이 : ", sum(map(len, X_train))/ len(X_train))
plt.hist([len(s) for s in X_train], bins=50) 
plt.xlabel('length of Data') 
plt.ylabel('number of Data')
plt.show()
# Out:
# 리뷰 최대 길이 :  125
# 리뷰 평균 길이 :  7.398229738807444

# %% [markdown]
# 원 핫 인코딩

# %%
import numpy as np 

y_train = [] 
y_test = []

for i in range(len(train_data['label'])): 
    if train_data['label'].iloc[i] == 1:
        y_train.append([0, 0, 1]) 
    elif train_data['label'].iloc[i] == 0: 
        y_train.append([0, 1, 0]) 
    elif train_data['label'].iloc[i] == -1: 
        y_train.append([1, 0, 0])
        
for i in range(len(test_data['label'])): 
    if test_data['label'].iloc[i] == 1: 
        y_test.append([0, 0, 1]) 
    elif test_data['label'].iloc[i] == 0: 
        y_test.append([0, 1, 0]) 
    elif test_data['label'].iloc[i] == -1: 
        y_test.append([1, 0, 0])

y_train = np.array(y_train) 
y_test = np.array(y_test)

# %%
y_train
# Out:
# array([[0, 0, 1],
#        [0, 1, 0],
#        [0, 1, 0],
#        ...,
#        [0, 0, 1],
#        [0, 1, 0],
#        [0, 1, 0]])

# %%
from keras.layers import Embedding, Dense, LSTM 
from keras.models import Sequential 
from keras.preprocessing.sequence import pad_sequences

max_len = 30

X_train = pad_sequences(X_train, maxlen=max_len) 
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
from tensorflow.python.ops.math_ops import reduce_prod
import numpy as np

# %%
model = Sequential() 
model.add(Embedding(max_words, 100)) 
model.add(LSTM(128)) 

model.add(Dense(3, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy']) #최적화를 adam으로 변경할 수 있음
history = model.fit(X_train, y_train, epochs=10, batch_size=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 2278/2278 [==============================] - 93s 39ms/step - loss: 0.4072 - accuracy: 0.8392 - val_loss: 0.3095 - val_accuracy: 0.8807
# Epoch 2/10
# 2278/2278 [==============================] - 93s 41ms/step - loss: 0.2929 - accuracy: 0.8823 - val_loss: 0.3013 - val_accuracy: 0.8882
# Epoch 3/10
# 2278/2278 [==============================] - 91s 40ms/step - loss: 0.2641 - accuracy: 0.8932 - val_loss: 0.2985 - val_accuracy: 0.8842
# Epoch 4/10
# 2278/2278 [==============================] - 89s 39ms/step - loss: 0.2416 - accuracy: 0.9038 - val_loss: 0.3157 - val_accuracy: 0.8720
# Epoch 5/10
# 2278/2278 [==============================] - 90s 39ms/step - loss: 0.2228 - accuracy: 0.9120 - val_loss: 0.3405 - val_accuracy: 0.8641
# Epoch 6/10
# 2278/2278 [==============================] - 88s 39ms/step - loss: 0.2071 - accuracy: 0.9197 - val_loss: 0.3444 - val_accuracy: 0.8688
# Epoch 7/10
# ...

# %%
print("\n 테스트 정확도 : {:.2f}%".format(model.evaluate(X_test, y_test)[1]*100))
# Out:
# 791/791 [==============================] - 6s 7ms/step - loss: 0.1557 - accuracy: 0.9431
#
#  테스트 정확도 : 94.31%

# %%
predict = model.predict(X_test)

# %%
import numpy as np 
predict_labels = np.argmax(predict, axis=1) 
original_labels = np.argmax(y_test, axis=1)

# %%
for i in range(100): 
    print("리뷰내용 : ", test_data['title'].iloc[i], "/\t 원래 점수 : ", original_labels[i], "/\t예측한 점수 : ", predict_labels[i])
# Out:
# 리뷰내용 :   사진 피코크 그릭요거트 이번에 처음 사봤어요
# 9개월아기 요거트쌀찐빵 만들어주려구요
# 대용량에 가격도 착해서 좋으네요 ㅎㅎ
# 만드는 방법은 특별하게 어렵진 않아요
# 요거트에 계란 노른자 분리해서 넣고
# 쌀가루로 농도조절하며 반죽했어요
# 혹시 단맛이 없어서 안먹을까싶어
# 단호박 큐브 만들어 놓은거 송송 다져 넣었어요 ㅎㅎ
# 찜기에 찌니까 폭신폭신 몰랑몰랑하네요 ㅎㅎ
# 너무 반죽이 질었던거 같아 오븐에도 살짝 돌려줬어요
# 요거트 향이 나면서 어른입맛엔 밍밍하지만
# 아이주도식중인데 아이도 손이 바로 가더라구요 ㅎㅎ
# 으깨고 입으  /	 원래 점수 :  2 /	예측한 점수 :  2
# 리뷰내용 :   사진 그릭요거트 라기엔 너무 묽어요ㅠㅠ
# 일반요거트랑 다른점 모르겠어요
# 유청 좀만 더 빼야할듯  /	 원래 점수 :  1 /	예측한 점수 :  1
# 리뷰내용 :   사진 처음 시켜봤는데 기대돼요  무설탕에 깔끔한 맛이라고 해서 맛있을것 같아요 샐러드용으로  먹어보려구요  /	 원래 점수 :  1 /	예측한 점수 :  1
# 리뷰내용 :   요거트가 다 터져서 배송됐어요 터진줄 모르고 꺼내다가 옷에 다 묻고 ㅜㅜ 터질 수 있는 제품은 포장을 더 신경써서 해야하는거 아닌가요 찝찝해서 먹을수도 없고 버리기엔 아깝고 짜증나네요  /	 원래 점수 :  1 /	예측한 점수 :  1
# 리뷰내용 :   포스트 그래놀라 먹을때 그릭요거트 위에 그래놀라 후르츠 뿌려서 먹어요 애들 아침 대용   우유랑만 먹다가 그릭요거트랑 주니까 쟐  먹네요 그릭요거트는 꾸덕해서 떠먹기좋아요 묽지않아요  /	 원래 점수 :  2 /	예측한 점수 :  2
# 리뷰내용 :   사진 생각보다 양은 적어요
# 약간 신맛이 있고 끝맛은 고소해요
# 무난합니다  /	 원래 점수 :  0 /	예측한 점수 :  0
# 리뷰내용 :   사진 달지않은 그릭요거트에요 다논 달지않은 그릭요거트맛 ㅋㅋ
# ...
